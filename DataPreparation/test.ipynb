# %%
import os
import json

# %%
os.chdir("/home/kiprono/Documents/STELLENBOSCH UNIVERISTY/\
Masters by Research/Mask RCNN/Annotation projects/fruits/train")

# %%
with open("via_project_fruits.json","r") as f:
    data = f.read()

# %%
data = json.loads(data)

annotations = list(data.values())
annotations[0]["filename"]
# Out:
# '_MG_3004_02.jpg'

# %%
all_images = []
for i in range(len(annotations)):
    print(annotations[i]["filename"])
    all_images.append(annotations[i]["filename"])
# Out:
# _MG_3004_02.jpg
# _MG_3004_03.jpg
# _MG_3004_04.jpg
# _MG_3004_05.jpg
# _MG_3004_08.jpg
# _MG_3004_09.jpg
# _MG_3004_10.jpg
# _MG_3004_13.jpg
# _MG_3004_14.jpg
# _MG_3004_15.jpg
# _MG_3004_17.jpg
# _MG_3004_19.jpg
# _MG_3004_20.jpg
# _MG_3004_22.jpg
# _MG_3017_01.jpg
# _MG_3017_03.jpg
# _MG_3017_04.jpg
# _MG_3017_08.jpg
# _MG_3017_09.jpg
# _MG_3017_10.jpg
# _MG_3017_11.jpg
# _MG_3017_13.jpg
# _MG_3017_14.jpg
# _MG_3017_15.jpg
# _MG_3017_16.jpg
# _MG_3017_19.jpg
# _MG_3017_20.jpg
# _MG_3017_21.jpg
# _MG_3168_01.jpg
# _MG_3168_02.jpg
# _MG_3168_04.jpg
# _MG_3168_05.jpg
# _MG_3168_06.jpg
# _MG_3168_07.jpg
# _MG_3168_09.jpg
# _MG_3168_10.jpg
# _MG_3168_11.jpg
# _MG_3168_12.jpg
# _MG_3168_14.jpg
# _MG_3168_15.jpg
# _MG_3168_16.jpg
# _MG_3168_17.jpg
# _MG_3168_19.jpg
# _MG_3168_20.jpg
# _MG_3168_21.jpg
# _MG_3168_22.jpg
# _MG_3168_24.jpg
# _MG_7954_01.jpg
# _MG_7954_02.jpg
# _MG_7954_03.jpg
# _MG_7954_05.jpg
# _MG_7954_06.jpg
# _MG_7954_07.jpg
# _MG_7954_08.jpg
# _MG_7954_10.jpg
# ...

# %%
len(all_images)
# Out:
# 2588

# %%
not_images = []
for image in os.listdir(os.getcwd()):
    if image not in all_images:
        not_images.append(image)
        #os.remove(os.path.join(os.getcwd(),image))

# %%
sorted(not_images)
# Out:
# ['0001-0001-1-49-0049.jpg',
#  '0001-0001-11444-28-95.jpg',
#  '0001-0001-11446-46-112.jpg',
#  '0001-0001-11446-49-112.jpg',
#  '0001-0001-11647-156-201.jpg',
#  '0001-0001-12013-252-304.jpg',
#  '0001-0001-2-95-0095.jpg',
#  '0001-0002-1-10-0010.jpg',
#  '0001-0002-11446-49-112.jpg',
#  '0001-0002-12013-252-304.jpg',
#  '0001-0002-12409-544-102.jpg',
#  '0001-0002-2-82-0082.jpg',
#  '0001-0005-1-128-0128.jpg',
#  '0001-0005-1-169-0169.jpg',
#  '0001-0005-1-25-0025.jpg',
#  '0001-11444-28-95.jpg',
#  '0001-11446-46-112.jpg',
#  '0001-11446-49-112.jpg',
#  '0001-11447-75-147.jpg',
#  '0001-11447-81-188.jpg',
#  '0001-11645-117-69.jpg',
#  '0001-12011-232-242.jpg',
#  '0001-2-39-0039.jpg',
#  '0001-2-82-0082.jpg',
#  '0001-2-95-0095.jpg',
#  '0002-0003-1-169-0169.jpg',
#  '0002-0004-1-118-0118.jpg',
#  '0002-0004-2-95-0095.jpg',
#  '0002-0006-11646-140-81.jpg',
#  '0002-0006-11647-156-201.jpg',
#  '0002-0006-11647-166-51.jpg',
#  '0002-0006-12014-253-337.jpg',
# ...
